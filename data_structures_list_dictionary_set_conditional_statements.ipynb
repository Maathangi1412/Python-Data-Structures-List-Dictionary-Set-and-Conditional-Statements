# %% [markdown]
# Python Assignment 2 – Data Structures – List, Dictionary, Set & Conditional Statements

# %% [markdown]
# 1. List – Creation, Modification and Access

# %%
age_list = [24, 25, 27, 28, 29]
name_list = ["Arun", "Bala", "Divya", "Kavya", "Meena"]

print("Age List:", age_list)
print("Name List:", name_list)
# Out:
# Age List: [24, 25, 27, 28, 29]
# Name List: ['Arun', 'Bala', 'Divya', 'Kavya', 'Meena']

# %% [markdown]
# 2. List Operations / Modifications

# %%
name_list.append("Yazhini")
print("After append:", name_list)

age_list.insert(2, 26)
print("After inserting 26:", age_list)

name_list.remove("Yazhini")
print("After removing Yazhini:", name_list)

age_list.pop()
print("After popping last element:", age_list)

age_list.extend([31, 30, 32])
print("After extending:", age_list)

age_list.sort(reverse=True)
print("Descending order:", age_list)

print("Maximum age:", max(age_list))
print("Minimum age:", min(age_list))
print("Sum of ages:", sum(age_list))
# Out:
# After append: ['Arun', 'Bala', 'Divya', 'Kavya', 'Meena', 'Yazhini']
# After inserting 26: [24, 25, 26, 27, 28, 29]
# After removing Yazhini: ['Arun', 'Bala', 'Divya', 'Kavya', 'Meena']
# After popping last element: [24, 25, 26, 27, 28]
# After extending: [24, 25, 26, 27, 28, 31, 30, 32]
# Descending order: [32, 31, 30, 28, 27, 26, 25, 24]
# Maximum age: 32
# Minimum age: 24
# Sum of ages: 223

# %% [markdown]
# 3. Accessing List Elements

# %%
print("First element:", name_list[0])
print("Last element:", name_list[-1])
print("Elements from index 2 to 4:", name_list[2:5])
print("Reverse order:", name_list[::-1])
# Out:
# First element: Arun
# Last element: Meena
# Elements from index 2 to 4: ['Divya', 'Kavya', 'Meena']
# Reverse order: ['Meena', 'Kavya', 'Divya', 'Bala', 'Arun']

# %% [markdown]
# 2. Dictionary – Creation, Modification and Access

# %%
student_marks = {
    "Arun": 75,
    "Bala": 68,
    "Divya": 90,
    "Kavya": 78,
    "Meena": 85
}

print("Divya's mark:", student_marks["Divya"])

student_marks["Janani"] = 80

student_marks["Bala"] = 82

print("Updated student marks:", student_marks)

print("Keys:", student_marks.keys())
print("Values:", student_marks.values())
print("Items:", student_marks.items())
# Out:
# Divya's mark: 90
# Updated student marks: {'Arun': 75, 'Bala': 82, 'Divya': 90, 'Kavya': 78, 'Meena': 85, 'Janani': 80}
# Keys: dict_keys(['Arun', 'Bala', 'Divya', 'Kavya', 'Meena', 'Janani'])
# Values: dict_values([75, 82, 90, 78, 85, 80])
# Items: dict_items([('Arun', 75), ('Bala', 82), ('Divya', 90), ('Kavya', 78), ('Meena', 85), ('Janani', 80)])

# %% [markdown]
# 3. Sets – Operations

# %%
my_set = {'a', 'e', 'i', 'o', 'u', 'a', 'a', 'i'}

print("my_set:", my_set)
# Out:
# my_set: {'o', 'a', 'e', 'u', 'i'}

# %% [markdown]
# Explanation
#
# Duplicate values are automatically removed because a set stores only unique elements.

# %%
try:
    print(my_set[4])
except TypeError:
    print("Error: Sets do not support indexing.")
# Out:
# Error: Sets do not support indexing.

# %% [markdown]
# Explanation
#
# Sets are unordered collections and do not support indexing. Therefore, my_set[4] gives a TypeError.

# %%
set1 = {1, 3, 5, 7, 9}
set2 = {2, 3, 5, 8, 10}

union_set = set1.union(set2)
intersection_set = set1.intersection(set2)

print("Set 1:", set1)
print("Set 2:", set2)
print("Union:", union_set)
print("Intersection:", intersection_set)
# Out:
# Set 1: {1, 3, 5, 7, 9}
# Set 2: {2, 3, 5, 8, 10}
# Union: {1, 2, 3, 5, 7, 8, 9, 10}
# Intersection: {3, 5}

# %% [markdown]
# ## 4. Operators & Conditional Statements – IF, ELIF, ELSE
#
# ### Performance Category Program

# %%
score = float(input("Enter your score (0 to 10): "))

if score < 0 or score > 10:
    print("Invalid score. Please enter a score between 0 and 10.")

elif score > 7:
    print("Above Average: Excellent performance! Keep up the great work.")

elif score >= 4:
    print("Average: Good effort! Keep practicing, there's room for improvement.")

else:
    print("Below Average: Need to improve your performance; consistent practice will lead to better results.")
# Out:
# Enter your score (0 to 10): 7
# Average: Good effort! Keep practicing, there's room for improvement.
